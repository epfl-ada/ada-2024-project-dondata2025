# %%
import pandas as pd

# Reading title basics
title_basics = pd.read_csv('title.basics.tsv', sep='\t', low_memory=False)
# Keeping only movies
title_basics = title_basics[title_basics['titleType'] == 'movie']
print(f"There are {len(title_basics)} movies in the dataset.")
title_basics.head()
# Out:
# There are 699260 movies in the dataset.
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                       Bohemios
# 570  tt0000574     movie    The Story of the Kelly Gang
# 587  tt0000591     movie               The Prodigal Son
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry       0      1894      \N             45
# 144  The Corbett-Fitzsimmons Fight       0      1897      \N            100
# 498                       Bohemios       0      1905      \N            100
# 570    The Story of the Kelly Gang       0      1906      \N             70
# 587              L'enfant prodigue       0      1907      \N             90
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 498                          \N
# 570  Action,Adventure,Biography
# 587                       Drama

# %%
# Reading title ratings
title_ratings = pd.read_csv('title.ratings.tsv', sep='\t', low_memory=False)
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2106
# 1  tt0000002            5.6       283
# 2  tt0000003            6.5      2128
# 3  tt0000004            5.4       182
# 4  tt0000005            6.2      2859

# %%
# Merging title basics and title ratings, to keep only primary title, original title, number of votes and average rating
title_basics_ratings = pd.merge(title_basics, title_ratings, on='tconst', how='inner')
title_basics_ratings = title_basics_ratings[['primaryTitle', 'originalTitle', 'numVotes', 'averageRating']]
title_basics_ratings.head()
# Out:
#                     primaryTitle                  originalTitle  numVotes  \
# 0                     Miss Jerry                     Miss Jerry       215
# 1  The Corbett-Fitzsimmons Fight  The Corbett-Fitzsimmons Fight       541
# 2                       Bohemios                       Bohemios        18
# 3    The Story of the Kelly Gang    The Story of the Kelly Gang       944
# 4               The Prodigal Son              L'enfant prodigue        28
#
#    averageRating
# 0            5.4
# 1            5.2
# 2            4.4
# 3            6.0
# 4            5.7

# %%
# Display the 10 movies with the highest average rating
title_basics_ratings.sort_values('averageRating', ascending=False).head(10)
# Out:
#                                              primaryTitle  \
# 222935                                             Rijali
# 231411                                            Zhuchok
# 262918  Trentatré - a Dream in the heart: Naples rises...
# 301692                                Mississippi Whistle
# 176096         The Church: Pillar and Ground of the Truth
# 186306     Superpower: Ignite Your Intuitive Intelligence
# 248261                      Northern Nights, Starry Skies
# 316732                           Poets Are the Destroyers
# 260500                                          Flashback
# 248255                                    The Tank Hunter
#
#                                             originalTitle  numVotes  \
# 222935                                             Rijali         7
# 231411                                            Zhuchok         7
# 262918  Trentatré - a Dream in the heart: Naples rises...        14
# 301692                                Mississippi Whistle         7
# 176096         The Church: Pillar and Ground of the Truth         7
# 186306     Superpower: Ignite Your Intuitive Intelligence         7
# 248261                      Northern Nights, Starry Skies         6
# 316732                           Poets Are the Destroyers         7
# 260500                                          Flashback        12
# 248255                                    The Tank Hunter       141
#
#         averageRating
# 222935           10.0
# 231411           10.0
# 262918           10.0
# 301692           10.0
# 176096           10.0
# 186306           10.0
# 248261           10.0
# 316732           10.0
# 260500           10.0
# 248255           10.0

# %% [markdown]
# Obviously not accurate without a threshold on amount of votes

# %%
# Display the 10 movies with the highest average rating and at least 100000 votes
title_basics_ratings[title_basics_ratings['numVotes'] >= 100000].sort_values('averageRating', ascending=False).head(10)
# Out:
#                                              primaryTitle  \
# 62544                            The Shawshank Redemption
# 37569                                       The Godfather
# 39488                               The Godfather Part II
# 24464                                        12 Angry Men
# 139619                                    The Dark Knight
# 80096       The Lord of the Rings: The Return of the King
# 60966                                    Schindler's List
# 62397                                        Pulp Fiction
# 67232   The Lord of the Rings: The Fellowship of the Ring
# 80097               The Lord of the Rings: The Two Towers
#
#                                             originalTitle  numVotes  \
# 62544                            The Shawshank Redemption   2970653
# 37569                                       The Godfather   2072012
# 39488                               The Godfather Part II   1398804
# 24464                                        12 Angry Men    896407
# 139619                                    The Dark Knight   2951998
# 80096       The Lord of the Rings: The Return of the King   2033401
# 60966                                    Schindler's List   1489566
# 62397                                        Pulp Fiction   2280695
# 67232   The Lord of the Rings: The Fellowship of the Ring   2063079
# 80097               The Lord of the Rings: The Two Towers   1833514
#
#         averageRating
# 62544             9.3
# 37569             9.2
# 39488             9.0
# 24464             9.0
# 139619            9.0
# 80096             9.0
# 60966             9.0
# 62397             8.9
# 67232             8.9
# 80097             8.8
