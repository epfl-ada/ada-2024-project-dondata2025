# %%
# Some basic imports 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# and more advanced ones
import os, codecs
import spacy, nltk
from collections import Counter

# %%
# Load plot summaries
with codecs.open(os.path.join('data/raw/', 'plot_summaries.txt'),encoding="utf8") as file:
    content = file.read()

# Load movies metadata
DATA_PATH = 'data/clean/movies_char/'

import src.data.movies_char_data as MovieChar

# %%
movie_df = MovieChar.MovieData("Movie", "movie.metadata.tsv", output_name = "movie_data_clean.csv")
movie_df.clean_raw_data()
movie_df.pipeline()
# Out:
# Movie : loaded 81740 rows !
# Movie : loaded 81740 rows !
# Movie : Clean data has been and saved to data/clean/movies_char/movie_data_clean.csv! (81740 rows)

# %%
character_df = MovieChar.CharacterData("Character", "character.metadata.tsv", output_name = "character_data_clean.csv")
character_df.clean_raw_data()
character_df.pipeline()
# Out:
# Character : loaded 450668 rows !
# Character : Cleaning the raw data
# Character : loaded 450668 rows !
# Character : Cleaning the raw data
# Character : Clean data has been and saved to data/clean/movies_char/character_data_clean.csv! (171826 rows)

# %%
from src.utils.movies_utils import *
mov_char_data = merge_movies_characters_data(movie_df, character_df)

mov_char_data.head()
# Out:
# Duplicates found: 412 duplicates ! removing them...
#    Wikipedia_movie_ID                                         Movie_name  \
# 0             3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 1             3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 2             3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 3             3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 4             3196793  Getting Away with Murder: The JonBenét Ramsey ...
#
#   Release_date  Revenue         Runtime Languages                 Countries  \
# 0   2000-02-16      NaN 0 days 01:35:00   English  United States of America
# 1   2000-02-16      NaN 0 days 01:35:00   English  United States of America
# 2   2000-02-16      NaN 0 days 01:35:00   English  United States of America
# 3   2000-02-16      NaN 0 days 01:35:00   English  United States of America
# 4   2000-02-16      NaN 0 days 01:35:00   English  United States of America
#
#                                            Genres             Character_name  \
# 0  Mystery, Biographical film, Drama, Crime Drama             POLICE OFFICER
# 1  Mystery, Biographical film, Drama, Crime Drama                   REPORTER
# 2  Mystery, Biographical film, Drama, Crime Drama  FBI PROFILER ROBERT HANKS
# 3  Mystery, Biographical film, Drama, Crime Drama                JOHN RAMSEY
# 4  Mystery, Biographical film, Drama, Crime Drama               PATSY RAMSEY
#
#    Actor_DOB Actor_gender  Actor_height      Actor_name  Actor_age
# 0        NaT            M           NaN    ALLEN CUTLER        NaN
# 1 1956-12-19            F           NaN   ALICE BARRETT       43.0
# 2 1950-01-05            M           NaN  ROBERT CATRINI       50.0
# 3 1945-02-12            M          1.85   CLIFF DEYOUNG       55.0
# 4 1964-07-12            F          1.63      JUDI EVANS       35.0

# %%
mov_char_data[mov_char_data['Movie_name'].str.contains('Narasimham')]
# Out:
#       Wikipedia_movie_ID  Movie_name Release_date  Revenue         Runtime  \
# 3403            20663735  Narasimham          NaT      NaN 0 days 02:55:00
# 3404            20663735  Narasimham          NaT      NaN 0 days 02:55:00
# 3405            20663735  Narasimham          NaT      NaN 0 days 02:55:00
#
#       Languages Countries                             Genres  \
# 3403  Malayalam     India  Musical, Action, Drama, Bollywood
# 3404  Malayalam     India  Musical, Action, Drama, Bollywood
# 3405  Malayalam     India  Musical, Action, Drama, Bollywood
#
#               Character_name  Actor_DOB Actor_gender  Actor_height  \
# 3403               BHARATHAN 1971-01-01            M           NaN
# 3404        NANDAGOPAL MARAR 1951-09-07            M          1.78
# 3405  MARANCHERI INDUCHOODAN 1960-05-21            M          1.72
#
#            Actor_name  Actor_age
# 3403  KALABHAVAN MANI       28.0
# 3404        MAMMOOTTY       48.0
# 3405         MOHANLAL       39.0

# %%
# Initialize the spacy model
nlp = spacy.load('en_core_web_sm')

# %%
def get_film_name(wiki_id):
    filtered_data = mov_char_data[mov_char_data['Wikipedia_movie_ID'] == wiki_id]
    if not filtered_data.empty:
        return filtered_data['Movie_name'].iloc[0]
    return None

# %%
# Function to tokenize the text
def tokenizer(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    return tokens

# %%
# Function to map characters to their corresponding actors
def map_characters_to_actors(name):
    # Strip spaces and convert to lowercase to avoid case and whitespace issues
    name = name.strip().lower()
    actor_name = 'Unknown Actor'
    
    # Iterate through all character names in mov_char_data to check for partial matches
    for char_name in mov_char_data['Character_name']:
        char_name_normalized = char_name.strip().lower()  # Normalize the character name
        
        # Check if the character name contains the input name as a substring
        if name in char_name_normalized:
            actor_name = mov_char_data[mov_char_data['Character_name'] == char_name]['Actor_name'].iloc[0]
            break  # Break once a match is found
    
    return actor_name

# %%
# Function to extract Names and filter 
def extract_names(text):
    # Initialize a Counter to store name frequencies
    name_counts = Counter() 
    doc = nlp(text)

    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            name_counts[ent.text] += 1
            
    # Consolidate similar names
    consolidated_counts = Counter()
    names = sorted(name_counts.keys(), key=len, reverse=True)  # Sort by length to prioritize full names

    for name in names:
        if any(name in longer_name and name != longer_name for longer_name in consolidated_counts):
            # If name is a substring of a longer name, add its count to the longer name
            for longer_name in consolidated_counts:
                if name in longer_name:
                    consolidated_counts[longer_name] += name_counts[name]
                    break
        else:
            consolidated_counts[name] = name_counts[name]

    # Sort names by count in descending order
    sorted_counts = consolidated_counts.most_common()  # Returns a list of (name, count) tuples sorted by count
    
    return sorted_counts

# %%
data = []
columns = ['Wikipedia ID','Film Name', 'Character Name','Actor Name', 'Count']

plots = content.strip().split("\n")  # Split the content by lines (each line is a film entry)
# Limit processing to the first 5 lines
plots_to_process = plots[:5]
for plot in plots_to_process:
    # Split each line into Wikipedia ID and Plot Summary
    film_data = plot.split("\t")

    if len(film_data) == 2:
        wikipedia_id = film_data[0]
        wikipedia_id = int(wikipedia_id)
        plot_summary = film_data[1]
        name_counts = extract_names(plot_summary)
        film_name = get_film_name(wikipedia_id)

        if film_name:  # Only process if film_name is not None
            for name_count in name_counts:
                name, count = name_count
                actor_name = map_characters_to_actors(name)
                data.append([wikipedia_id, film_name, name, actor_name, count])
        
# Create a dataframe to store the data
df = pd.DataFrame(data, columns=columns)
df
# Out:
#     Wikipedia ID          Film Name              Character Name  \
# 0       31186339   The Hunger Games               Peeta Mellark
# 1       31186339   The Hunger Games                     Katniss
# 2       31186339   The Hunger Games          Haymitch Abernathy
# 3       31186339   The Hunger Games                Seneca Crane
# 4       31186339   The Hunger Games                        Snow
# 5       31186339   The Hunger Games                         Rue
# 6       31186339   The Hunger Games                      Thresh
# 7       31186339   The Hunger Games                       baker
# 8       31186339   The Hunger Games                        Cato
# 9       20663735         Narasimham  Manapally Madhavan Nambiar
# 10      20663735         Narasimham            Karunakara Menon
# 11      20663735         Narasimham                   Indulekha
# 12      20663735         Narasimham                    Anuradha
# 13      20663735         Narasimham       DYSP Sankaranarayanan
# 14      20663735         Narasimham        Poovalli Induchoodan
# 15      20663735         Narasimham         Manapally Sudheeran
# 16      20663735         Narasimham         Manapally Pavithran
# 17      20663735         Narasimham           Nandagopal Maarar
# 18      20663735         Narasimham                Mooppil Nair
# 19      20663735         Narasimham                Jayakrishnan
# 20      20663735         Narasimham                 Moopil Nair
# 21      20663735         Narasimham                  Raman Nair
# 22      20663735         Narasimham                      Kanaka
# 23        595909  A Cry in the Dark                       Lindy
# 24        595909  A Cry in the Dark         Michael Chamberlain
# 25        595909  A Cry in the Dark                      Azaria
# 26        595909  A Cry in the Dark                      Gossip
#
#            Actor Name  Count
# 0     JOSH HUTCHERSON      5
# 1   JENNIFER LAWRENCE      4
# 2     WOODY HARRELSON      3
# 3         WES BENTLEY      2
# 4          MEL BROOKS      2
# 5      ROBERT ENGLUND      2
# 6         MARK HAMILL      1
# 7        KEVIN DOWNES      1
# 8   VINCENZO TALARICO      1
# 9       Unknown Actor      5
# 10      Unknown Actor      5
# 11     MAMTA MOHANDAS      5
# 12     ANUSHKA SHETTY      2
# 13      Unknown Actor      1
# 14      Unknown Actor      1
# 15      Unknown Actor      1
# 16      Unknown Actor      1
# 17      Unknown Actor      1
# 18      Unknown Actor      1
# 19           MOHANLAL      1
# 20      Unknown Actor      1
# 21            BAHADUR      1
# 22     BINDU PANICKER      1
# 23      ABBIE CORNISH      5
# 24          SAM NEILL      4
# 25      Unknown Actor      3
# 26    VIRGINIA GRAHAM      1
